# %%
import os
import io
import pandas as pd
import zipfile
import geopandas as  gpd
import numpy as np
from sklearn.cluster import KMeans, DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import seaborn
import datetime
import requests
import json
import pylab as pl
# %pylab inline
# Out:
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
# Populating the interactive namespace from numpy and matplotlib

# %% [raw]
# #these commands can be run on the shell and get the data with the command wget
# #the cell needs to be run only once
# !for ((y=93; y<=99; y+=1)); do wget \
# ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp$y\totals.zip; done
#
# !for ((y=0; y<=1; y+=1)); do wget \
# ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp0$y\totals.zip; done
#
# !for ((y=2; y<=9; y+=1)); do wget \
# ftp://ftp.census.gov/econ200$y\/CBP_CSV/zbp0$y\totals.zip; done
#
# !for ((y=10; y<=14; y+=1)); do wget \
# ftp://ftp.census.gov/econ20$y\/CBP_CSV/zbp$y\totals.zip; done

# %%
import os

# %%
fname = "zbp00totals.zip"

# %% [markdown]
# <br/>

# %%
import pandas as pd
import zipfile 
zf = zipfile.ZipFile(fname)
zf
# Out:
# <zipfile.ZipFile filename='zbp00totals.zip' mode='r'>

# %%
zf.open(fname.replace('.zip','.txt'))
# Out:
# <zipfile.ZipExtFile name='zbp00totals.txt' mode='r' compress_type=deflate>

# %%
df = pd.read_csv(zf.open(fname.replace('.zip','.txt')))
df.head(5)
# Out:
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY       A     0      0       0    1
# 1  1001      AGAWAM, MA     NaN  8042  59833  259661  493
# 2  1002     AMHERST, MA     NaN  6547  36719  169658  563
# 3  1003     AMHERST, MA     NaN    82    308    2482   13
# 4  1004     AMHERST, MA     NaN   717   2049    5826   48

# %% [markdown]
# ## 1. Load NYC Zipcode Zone

# %%
FilePath = os.getenv("PUIDATA")+"/HW11/"
os.chdir(FilePath)

zipNYC = gpd.read_file("ZIP_CODE_040114.shp")
# Change ColNames 
zipNYC.head(100)
# Out:
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
#    ZIPCODE BLDGZIP           PO_NAME  POPULATION          AREA STATE  \
# 0    11436       0           Jamaica     18681.0  2.269930e+07    NY
# 1    11213       0          Brooklyn     62426.0  2.963100e+07    NY
# 2    11212       0          Brooklyn     83866.0  4.197210e+07    NY
# 3    11225       0          Brooklyn     56527.0  2.369863e+07    NY
# 4    11218       0          Brooklyn     72280.0  3.686880e+07    NY
# 5    11226       0          Brooklyn    106132.0  3.940860e+07    NY
# 6    11219       0          Brooklyn     92561.0  4.200274e+07    NY
# 7    11210       0          Brooklyn     67067.0  4.788702e+07    NY
# 8    11230       0          Brooklyn     80857.0  4.992670e+07    NY
# 9    11204       0          Brooklyn     77354.0  4.355518e+07    NY
# 10   10471       0             Bronx     23477.0  8.965141e+07    NY
# 11   10470       0             Bronx     14740.0  2.154346e+07    NY
# 12   10466       0             Bronx     68942.0  5.526249e+07    NY
# 13   10467       0             Bronx     97932.0  6.933617e+07    NY
# 14   10463       0             Bronx     70641.0  3.670338e+07    NY
# 15   10475       0             Bronx     40931.0  3.863330e+07    NY
# 16   10464       0             Bronx      4438.0  7.625748e+07    NY
# 17   10469       0             Bronx     65101.0  6.804089e+07    NY
# 18   10468       0             Bronx     72877.0  3.444760e+07    NY
# 19   10463       0             Bronx     70641.0  3.119702e+06    NY
# 20   10458       0             Bronx     79362.0  3.596881e+07    NY
# 21   10034       0          New York     39149.0  2.450389e+07    NY
# 22   10033       0          New York     54284.0  1.615605e+07    NY
# 23   10462       0             Bronx     75674.0  5.302251e+07    NY
# 24   10040       0          New York     41033.0  1.634074e+07    NY
# 25   10453       0             Bronx     77576.0  2.574851e+07    NY
# 26   10465       0             Bronx     42012.0  1.084237e+08    NY
# 27   10464       0             Bronx      4438.0  4.512531e+06    NY
# 28   10464       0             Bronx      4438.0  1.158795e+07    NY
# 29   10461       0             Bronx     50549.0  6.282406e+07    NY
# ..     ...     ...               ...         ...           ...   ...
# 70   11369       0     East Elmhurst     38116.0  3.006049e+07    NY
# 71   11103       0           Astoria     38234.0  2.022239e+07    NY
# 72   11106       0           Astoria     38665.0  2.386611e+07    NY
# 73   11368       0            Corona    109069.0  7.248966e+07    NY
# 74   11377       0          Woodside     90852.0  7.183239e+07    NY
# 75   11355       0          Flushing     82809.0  4.938308e+07    NY
# 76   11101       0  Long Island City     26254.0  7.896209e+07    NY
# 77   11364       0   Oakland Gardens     33937.0  8.425967e+07    NY
# 78   10018       0          New York      5503.0  1.070580e+07    NY
# 79   10020       0          New York         0.0  6.972970e+05    NY
# 80   11005       0       Floral Park      3533.0  9.075527e+06    NY
# 81   10017       0          New York     15918.0  9.794383e+06    NY
# 82   10001       0          New York     22413.0  1.779494e+07    NY
# 83   10011       0          New York     50594.0  1.811842e+07    NY
# 84   10016       0          New York     54606.0  1.504240e+07    NY
# 85   11104       0         Sunnyside     27127.0  1.208443e+07    NY
# 86   11109       0  Long Island City      2752.0  5.812372e+05    NY
# 87   10010       0          New York     29881.0  9.768396e+06    NY
# 88   11367       0          Flushing     41773.0  7.281015e+07    NY
# 89   10014       0          New York     31328.0  1.415105e+07    NY
# 90   10003       0          New York     55878.0  1.553838e+07    NY
# 91   11222       0          Brooklyn     36315.0  4.282529e+07    NY
# 92   10002       0          New York     81305.0  2.628013e+07    NY
# 93   11378       0           Maspeth     35473.0  6.626054e+07    NY
# 94   10009       0          New York     61455.0  1.590352e+07    NY
# 95   10012       0          New York     24276.0  9.193739e+06    NY
# 96   10013       0          New York     27985.0  1.558058e+07    NY
# 97   10007       0          New York      7323.0  5.327871e+06    NY
# 98   11237       0          Brooklyn     49335.0  2.742587e+07    NY
# 99   11385       0         Ridgewood     98436.0  1.247863e+08    NY
#
#       COUNTY ST_FIPS CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0     Queens      36      081  http://www.usps.com/         0.0        0.0
# 1      Kings      36      047  http://www.usps.com/         0.0        0.0
# 2      Kings      36      047  http://www.usps.com/         0.0        0.0
# 3      Kings      36      047  http://www.usps.com/         0.0        0.0
# 4      Kings      36      047  http://www.usps.com/         0.0        0.0
# 5      Kings      36      047  http://www.usps.com/         0.0        0.0
# 6      Kings      36      047  http://www.usps.com/         0.0        0.0
# 7      Kings      36      047  http://www.usps.com/         0.0        0.0
# 8      Kings      36      047  http://www.usps.com/         0.0        0.0
# 9      Kings      36      047  http://www.usps.com/         0.0        0.0
# 10     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 11     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 12     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 13     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 14     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 15     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 16     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 17     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 18     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 19  New York      36      061  http://www.usps.com/         0.0        0.0
# 20     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 21  New York      36      061  http://www.usps.com/         0.0        0.0
# 22  New York      36      061  http://www.usps.com/         0.0        0.0
# 23     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 24  New York      36      061  http://www.usps.com/         0.0        0.0
# 25     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 26     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 27     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 28     Bronx      36      005  http://www.usps.com/         0.0        0.0
# 29     Bronx      36      005  http://www.usps.com/         0.0        0.0
# ..       ...     ...      ...                   ...         ...        ...
# 70    Queens      36      081  http://www.usps.com/         0.0        0.0
# 71    Queens      36      081  http://www.usps.com/         0.0        0.0
# 72    Queens      36      081  http://www.usps.com/         0.0        0.0
# 73    Queens      36      081  http://www.usps.com/         0.0        0.0
# 74    Queens      36      081  http://www.usps.com/         0.0        0.0
# 75    Queens      36      081  http://www.usps.com/         0.0        0.0
# 76    Queens      36      081  http://www.usps.com/         0.0        0.0
# 77    Queens      36      081  http://www.usps.com/         0.0        0.0
# 78  New York      36      061  http://www.usps.com/         0.0        0.0
# 79  New York      36      061  http://www.usps.com/         0.0        0.0
# 80    Queens      36      081  http://www.usps.com/         0.0        0.0
# 81  New York      36      061  http://www.usps.com/         0.0        0.0
# 82  New York      36      061  http://www.usps.com/         0.0        0.0
# 83  New York      36      061  http://www.usps.com/         0.0        0.0
# 84  New York      36      061  http://www.usps.com/         0.0        0.0
# 85    Queens      36      081  http://www.usps.com/         0.0        0.0
# 86    Queens      36      081  http://www.usps.com/         0.0        0.0
# 87  New York      36      061  http://www.usps.com/         0.0        0.0
# 88    Queens      36      081  http://www.usps.com/         0.0        0.0
# 89  New York      36      061  http://www.usps.com/         0.0        0.0
# 90  New York      36      061  http://www.usps.com/         0.0        0.0
# 91     Kings      36      047  http://www.usps.com/         0.0        0.0
# 92  New York      36      061  http://www.usps.com/         0.0        0.0
# 93    Queens      36      081  http://www.usps.com/         0.0        0.0
# 94  New York      36      061  http://www.usps.com/         0.0        0.0
# 95  New York      36      061  http://www.usps.com/         0.0        0.0
# 96  New York      36      061  http://www.usps.com/         0.0        0.0
# 97  New York      36      061  http://www.usps.com/         0.0        0.0
# 98     Kings      36      047  http://www.usps.com/         0.0        0.0
# 99    Queens      36      081  http://www.usps.com/         0.0        0.0
#
#                                              geometry
# 0   POLYGON ((1038098.251871482 188138.3800067157,...
# 1   POLYGON ((1001613.712964058 186926.4395172149,...
# 2   POLYGON ((1011174.275535807 183696.33770971, 1...
# 3   POLYGON ((995908.3654508889 183617.6128015518,...
# 4   POLYGON ((991997.1134308875 176307.4958601296,...
# 5   POLYGON ((994821.4729396403 177865.7178093046,...
# 6   POLYGON ((987286.3515269756 173946.4621963799,...
# 7   POLYGON ((995796.0097044706 171110.0666224658,...
# 8   POLYGON ((994099.2959063053 171240.7064530551,...
# 9   POLYGON ((989500.1699339747 170730.1687602103,...
# 10  POLYGON ((1016890.088579223 269622.9437433034,...
# 11  POLYGON ((1018000.867525637 269218.6804442108,...
# 12  POLYGON ((1027197.215602726 268941.3607888818,...
# 13  POLYGON ((1017396.305742651 265444.4701448828,...
# 14  POLYGON ((1006191.4413414 262532.3198012114, 1...
# 15  POLYGON ((1032020.225313649 263914.7786504626,...
# 16  POLYGON ((1035294.156757891 263362.0300840437,...
# 17  POLYGON ((1024100.416350141 261325.2041052133,...
# 18  POLYGON ((1015493.785269484 260806.2185946256,...
# 19  POLYGON ((1007634.817063555 258290.334846884, ...
# 20  POLYGON ((1016105.938572735 259343.7165983766,...
# 21  POLYGON ((1006203.169008225 257345.6566181332,...
# 22  POLYGON ((1003020.86467731 256049.1618358046, ...
# 23  POLYGON ((1020069.122247398 251522.9376205504,...
# 24  POLYGON ((1002564.135275811 253724.7731118798,...
# 25  POLYGON ((1011926.555855393 251674.4530655444,...
# 26  POLYGON ((1028758.870287806 243777.018401131, ...
# 27  POLYGON ((1047319.759675145 251630.1185085475,...
# 28  POLYGON ((1041692.690220639 251236.5385870486,...
# 29  POLYGON ((1029230.779448971 251468.9475710541,...
# ..                                                ...
# 70  POLYGON ((1015324.173403978 218811.9059298784,...
# 71  POLYGON ((1007984.626075223 220374.942830056, ...
# 72  POLYGON ((1002403.48664698 220245.6560151279, ...
# 73  POLYGON ((1022299.623363808 218703.9081143886,...
# 74  POLYGON ((1011389.065460563 218882.4533609599,...
# 75  POLYGON ((1029167.913432971 214195.5490208864,...
# 76  POLYGON ((996450.6599699706 210544.1442502141,...
# 77  POLYGON ((1045257.876659811 213288.8638263792,...
# 78  POLYGON ((983778.6019808054 216668.1490625441,...
# 79  POLYGON ((990566.3797438145 215633.2423397154,...
# 80  POLYGON ((1063782.437051564 216277.1357369721,...
# 81  POLYGON ((990440.5063079 215404.9508015513, 99...
# 82  POLYGON ((981958.6472873986 213464.4530421346,...
# 83  POLYGON ((986378.4337233901 210178.5990495533,...
# 84  POLYGON ((989286.3432618976 213322.780097127, ...
# 85  POLYGON ((1009231.627518222 213124.9530649632,...
# 86  POLYGON ((995983.2714690566 211172.9510634691,...
# 87  POLYGON ((987500.0003778934 210146.4376965463,...
# 88  POLYGON ((1029249.074031815 210099.8554406315,...
# 89  POLYGON ((983985.4854253083 205856.7261316329,...
# 90  POLYGON ((989830.469142139 207048.1263078749, ...
# 91  POLYGON ((996935.7633304745 208556.5094459653,...
# 92  POLYGON ((991339.8703228086 207576.7837151289,...
# 93  POLYGON ((1008954.707796484 205203.5827528834,...
# 94  POLYGON ((991606.4032543153 205494.1464762092,...
# 95  POLYGON ((985200.0558308065 205072.0203519613,...
# 96  POLYGON ((983216.1014653891 203868.9381124675,...
# 97  POLYGON ((980538.9073447287 200658.5114624649,...
# 98  POLYGON ((1005006.704865724 199410.7685511261,...
# 99  POLYGON ((1007499.885246813 199242.4519586265,...
#
# [100 rows x 13 columns]

# %%
zipNYC.columns
# Out:
# Index(['ZIPCODE', 'BLDGZIP', 'PO_NAME', 'POPULATION', 'AREA', 'STATE',
#        'COUNTY', 'ST_FIPS', 'CTY_FIPS', 'URL', 'SHAPE_AREA', 'SHAPE_LEN',
#        'geometry'],
#       dtype='object')

# %%
#zipNYC = zipNYC.rename(columns={'postalCode': "zipcode"})
zipNYC = zipNYC[['ZIPCODE', 'geometry', 'COUNTY', 'PO_NAME']]
zipNYC.ZIPCODE = pd.to_numeric(zipNYC.ZIPCODE)
zipNYC.head()
# Out:
#    ZIPCODE                                           geometry  COUNTY  \
# 0    11436  POLYGON ((1038098.251871482 188138.3800067157,...  Queens
# 1    11213  POLYGON ((1001613.712964058 186926.4395172149,...   Kings
# 2    11212  POLYGON ((1011174.275535807 183696.33770971, 1...   Kings
# 3    11225  POLYGON ((995908.3654508889 183617.6128015518,...   Kings
# 4    11218  POLYGON ((991997.1134308875 176307.4958601296,...   Kings
#
#     PO_NAME
# 0   Jamaica
# 1  Brooklyn
# 2  Brooklyn
# 3  Brooklyn
# 4  Brooklyn

# %%
def check_zipcode(zipNYC):
    '''
    check_zipcode is consistant or not
    input: dataframe contains zipcode information
    output: numerical unique zipcode list zipcode_list
    '''

    # Unique Zipcode in NYC
    print ("# of All Zipcode: ", zipNYC.ZIPCODE.unique().shape[0])
    print ("# of Unique Zipcode: ", zipNYC.shape[0])

    # (Numeric) NYC Zipcode LIST
    zipNYCList = pd.to_numeric(zipNYC.ZIPCODE).values

    # (Numeric NYC Zipcode UNIQUE LIST
    zipNYCList_Unique = np.unique(zipNYCList)
    
    return zipNYCList_Unique,zipNYCList

zipNYCList_Unique,zipNYCList = check_zipcode(zipNYC)
# Out:
# # of All Zipcode:  248
# # of Unique Zipcode:  263

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## 2. Load and Merge Census Business Data

# %%
# Create a copy of zipNYC
zip_merged = zipNYC.copy()

# create curated year list
year = datetime.datetime.today().year -1
YEARS = map(str,range(year-2, year - 23, -1))
YEARS = map(lambda x:x[2:4],YEARS)

# %%
def merged_business(YEARS, zip_merged,zipNYCList):
    '''
    merged all the business files
    
    input: year range and original zipcode list
    output: CB
    '''
    
    # Merge(1994-2014)
    for year in YEARS:
        # Name
        fname = str('zbp' + year + 'totals.zip')
        #print(year)
        colname_EST = str('EST' + year)  # colname of new adding column
        # Load
        zf = zipfile.ZipFile(fname)
        df = pd.read_csv(zf.open(fname.replace('.zip','.txt')))
        df.columns = map(str.upper, df.columns) # since there are cases 'ZIP' and 'EST' are lowercases.
        # Filter
        CB_NYC = df[np.in1d(df.ZIP, zipNYCList)].loc[:,['ZIP','EST']]
        # Merge
        CB_NYC = CB_NYC.rename(columns={'ZIP': 'ZIPCODE'})
        zip_merged = pd.merge(zip_merged, CB_NYC, on='ZIPCODE')
        # Colname
        zip_merged = zip_merged.rename(columns={"EST": colname_EST})

    # create CB to store merged data
    CB = zip_merged
    return CB

CB = merged_business(YEARS, zip_merged,zipNYCList)

# %%
CB.head(5)
# Out:
#    ZIPCODE                                           geometry  COUNTY  \
# 0    11436  POLYGON ((1038098.251871482 188138.3800067157,...  Queens
# 1    11213  POLYGON ((1001613.712964058 186926.4395172149,...   Kings
# 2    11212  POLYGON ((1011174.275535807 183696.33770971, 1...   Kings
# 3    11225  POLYGON ((995908.3654508889 183617.6128015518,...   Kings
# 4    11218  POLYGON ((991997.1134308875 176307.4958601296,...   Kings
#
#     PO_NAME  EST14  EST13  EST12  EST11  EST10  EST09  ...    EST03  EST02  \
# 0   Jamaica    109     99     95    101     98     92  ...       74     78
# 1  Brooklyn    772    755    726    674    675    621  ...      569    546
# 2  Brooklyn    752    731    721    713    699    647  ...      581    577
# 3  Brooklyn    696    673    623    597    580    543  ...      488    479
# 4  Brooklyn   1736   1687   1605   1523   1474   1457  ...     1247   1228
#
#    EST01  EST00  EST99  EST98  EST97  EST96  EST95  EST94
# 0     57     65     58     51     51     53     50     51
# 1    493    477    473    476    456    433    420    406
# 2    527    520    541    519    527    502    494    505
# 3    422    417    409    416    410    388    387    381
# 4   1180   1161   1149   1118   1075   1049   1015    985
#
# [5 rows x 25 columns]

# %%
# Create a copy of zipNYC
zip_merged = zipNYC.copy()

# create curated year list
year = datetime.datetime.today().year
YEARS = map(str,range(year-2, year - 23, -1))
YEARS = map(lambda x:x[2:4],YEARS)

def merged_business(YEARS, zip_merged,zipNYCList):
    '''
    merged all the business files
    
    input: year range and original zipcode list
    output: CB
    '''
    
    # Merge(1994-2014)
    for year in YEARS:
        # Name
        fname = str('zbp' + year + 'totals.zip')
        colname_EST = str('EST' + year)  # colname of new adding column
        # Load
        zf = zipfile.ZipFile(fname)
        df = pd.read_csv(zf.open(fname.replace('.zip','.txt')))
        df.columns = map(str.upper, df.columns) # since there are cases 'ZIP' and 'EST' are lowercases.
        # Filter
        CB_NYC = df[np.in1d(df.ZIP, zipNYCList)].loc[:,['ZIP','EST']]
        # Merge
        CB_NYC = CB_NYC.rename(columns={'ZIP': 'zipcode'})
        zip_merged = pd.merge(zip_merged, CB_NYC, on='zipcode')
        # Colname
        zip_merged = zip_merged.rename(columns={"EST": colname_EST})

    # create CB to store merged data
    CB = zip_merged
    return CB

CB = merged_business(YEARS, zip_merged,zipNYCList)

# %% [markdown]
# ## 3. Standardlized CB

# %%
CB_mean = CB.iloc[:,range(4,25)].mean(axis=1)
CB_std = CB.iloc[:,range(4,25)].std(axis=1)
CB.iloc[:,range(4,25)] = CB.iloc[:,range(4,25)].apply(lambda x: (x- CB_mean) / CB_std)

# %%
CB.head(2)
# Out:
#    ZIPCODE                                           geometry  COUNTY  \
# 0    11436  POLYGON ((1038098.251871482 188138.3800067157,...  Queens
# 1    11213  POLYGON ((1001613.712964058 186926.4395172149,...   Kings
#
#     PO_NAME     EST14     EST13     EST12     EST11     EST10     EST09  \
# 0   Jamaica  1.676853  1.164278  0.959248  1.266793  1.113020  0.805475
# 1  Brooklyn  1.920875  1.765058  1.499252  1.022634  1.031799  0.536850
#
#      ...        EST03    EST02     EST01     EST00     EST99     EST98  \
# 0    ...    -0.117160  0.08787 -0.988538 -0.578478 -0.937280 -1.296083
# 1    ...     0.060232 -0.15058 -0.636364 -0.783015 -0.819678 -0.792181
#
#       EST97     EST96     EST95     EST94
# 0 -1.296083 -1.193568 -1.347340 -1.296083
# 1 -0.975496 -1.186307 -1.305462 -1.433782
#
# [2 rows x 25 columns]

# %%
CB.columns
# Out:
# Index(['ZIPCODE', 'geometry', 'COUNTY', 'PO_NAME', 'EST14', 'EST13', 'EST12',
#        'EST11', 'EST10', 'EST09', 'EST08', 'EST07', 'EST06', 'EST05', 'EST04',
#        'EST03', 'EST02', 'EST01', 'EST00', 'EST99', 'EST98', 'EST97', 'EST96',
#        'EST95', 'EST94'],
#       dtype='object')

# %%
result = CB.iloc[:,range(4,25)].copy()
result.columns = [i for i in range(1994,2015)]
plt.figure(figsize=(10,4))
plt.xlim(1994,2014)
for i in range(len(result)):
    #print(result.iloc[i])
    plt.plot(result.iloc[i],'k',alpha=0.5)

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## 4. KMeans

# %%
mod_km = KMeans(n_clusters=4, init='k-means++', n_init=10, max_iter=500, tol=0.0001, 
                verbose=0, random_state=None).fit(CB.iloc[:,range(4,25)])

# %%
centers = mod_km.cluster_centers_

# %% [markdown]
# ### For Example, set EST94 and EST14 as x/y axis and plot cluster centers

# %%
pl.figure(figsize=(8,8))
pl.scatter(CB[mod_km.labels_ == 0].iloc[:,4], CB[mod_km.labels_ == 0].iloc[:,24], \
           color='lightblue', alpha=0.3, label="Cluster 1")
pl.scatter(centers[0][0], centers[0][-1], marker='o', s=100, color='blue', label="Cluster 1 Center")

pl.scatter(CB[mod_km.labels_ == 1].iloc[:,4], CB[mod_km.labels_ == 1].iloc[:,24], \
           color='red', alpha=0.3, label="Cluster 2")
pl.scatter(centers[1][0], centers[1][-1], marker='o', s=100, color='red', label="Cluster 2 Center")

pl.scatter(CB[mod_km.labels_ == 2].iloc[:,4], CB[mod_km.labels_ == 2].iloc[:,24], \
           color='green', alpha=0.3, label="Cluster 3")
pl.scatter(centers[2][0], centers[2][-1], marker='o', s=100, color='green', label="Cluster 3 Center")

pl.scatter(CB[mod_km.labels_ == 3].iloc[:,4], CB[mod_km.labels_ == 3].iloc[:,24], \
           color='purple', alpha=0.3, label="Cluster 4")
pl.scatter(centers[3][0], centers[3][-1], marker='o', s=100, color='purple', label="Cluster 4 Center")

# pl.scatter(CB[mod_km.labels_ == 4].iloc[:,4], CB[mod_km.labels_ == 4].iloc[:,24], \
#            color='orange', alpha=0.3, label="Cluster 5")
# pl.scatter(centers[4][0], centers[4][-1], marker='*', s=100, color='orange', label="Cluster 5 Center")

pl.xlabel("EST94")
pl.ylabel("EST14")
pl.title("KMeans Cluster: The Number Of ESTABLISHMENTS")
pl.legend(fontsize=10, loc='best')

# %% [markdown]
# #### KMeans Cluster for EST94~EST14 has shown in above plot. The Figure that data points from different clusters gather aroud their own cluster centers with a little overlap.

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## 5. DBSCAN

# %%
mod_DBSCAN = DBSCAN(min_samples=4).fit(CB.iloc[:,range(4,25)])

# %%
unique(mod_DBSCAN.labels_)
# Out:
# array([-1,  0,  1,  2,  3])

# %% [markdown]
# ### DBSCAN: 5 Clusters In Total

# %% [markdown]
# ## 6. Hierarchical Clustering

# %%
Z = linkage(CB.iloc[:,range(4,25)], 'ward')

# %%
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
pl.show()

# %% [markdown]
# ### Plot above shows the result of hierarchical clustering.

# %%
HC_label = fcluster(Z, 4, criterion='maxclust')

# %% [markdown]
# <br/><br/>
# ## 7. Plot

# %%
CB2 = CB.copy()
CB2['km'] = mod_km.labels_
CB2['DBSCAN'] = mod_DBSCAN.labels_
CB2['HC'] = HC_label
CB2['HC_'] = CB2.HC.replace([1,4],[4,1])

# %%
f, (ax1, ax2, ax3) = pl.subplots(1,3,figsize=(60,20))
CB2.plot(colormap='OrRd', column='km', ax=ax1, categorical=True, k=4)
ax1.set_title("KMeans, k=4", fontsize=50)
CB2.plot(colormap='OrRd', column='HC_', ax=ax2, categorical=True, k=4)
ax2.set_title("Hierarchical Clustering, k=4", fontsize=50)
CB2.plot(colormap='OrRd', column='DBSCAN', ax=ax3, categorical=True, k=5)
ax3.set_title("DBSCAN, k=5", fontsize=50)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/geopandas/plotting.py:381: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   "(for consistency with matplotlib)", FutureWarning)
# Text(0.5,1,'DBSCAN, k=5')

# %% [markdown]
# ### Above Plots shows cluster result of three clustering methods (k-means, Hierarchical Clustering and DBSCN)

# %% [markdown]
# <br/><br/>
# ## 8. Interpretation and Exploration

# %% [markdown]
# Overall, the clustering results are similar to each other. What I think is really interesting is the results show that the pattern of some area in manhattan is similar in south brooklyn
